# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Looking Over the Data

# %%
# 1 load in the data
df = pd.read_csv('mushroom_data.csv', sep=',')
df.head(10)
# Out:
#        Class Cap Shape Cap Surface Cap Color  Bruises     Odor  \
# 0  Poisonous    Convex      Smooth     Brown     True  Pungent
# 1     Edible    Convex      Smooth    Yellow     True   Almond
# 2     Edible      Bell      Smooth     White     True    Anise
# 3  Poisonous    Convex       Scaly     White     True  Pungent
# 4     Edible    Convex      Smooth      Gray    False      NaN
# 5     Edible    Convex       Scaly    Yellow     True   Almond
# 6     Edible      Bell      Smooth     White     True   Almond
# 7     Edible      Bell       Scaly     White     True    Anise
# 8  Poisonous    Convex       Scaly     White     True  Pungent
# 9     Edible      Bell      Smooth    Yellow     True   Almond
#
#   Gill Attachment Gill Spacing Gill Size Gill Color  ...  \
# 0            Free        Close    Narrow      Black  ...
# 1            Free        Close     Broad      Black  ...
# 2            Free        Close     Broad      Brown  ...
# ...

# %% [markdown]
# The dataset contains 23 columns of data describing thousands of mushrooms.
# The types of data are mostly categorical. It is possible to visualize most of them with bar graphs.

# %% [markdown]
# ## Plotting Bar Graphs

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.countplot(x=df['Stalk Root'], palette='Set1', hue=df['Stalk Root'], legend=False, order=df['Stalk Root'].value_counts().index)
plt.title(f"Stalk Root barplot")
plt.xticks(rotation=30, fontsize=8)

plt.subplot(1, 2, 2)
wedge_sizes = df['Stalk Root'].value_counts(normalize=True)
pie_labels = wedge_sizes.index

plt.pie(wedge_sizes, labels=pie_labels, autopct='%1.1f%%')
plt.axis('equal')
plt.title(f"Stalk Root pieplot")

plt.subplots_adjust(left=0.05, bottom=0.05, right=0.95, top=0.95, wspace=0.3, hspace=0.3)
plt.show()

# %%
def barplot(df, column_name):
    sns.countplot(x=df[column_name], palette='Set1', hue=df[column_name], legend=False, order=df[column_name].value_counts().index)
    plt.title(f"{column_name} barplot")
    plt.xticks(rotation=30, fontsize=8)
    plt.xlabel(column_name, fontsize=12)
    plt.show()

# %%
# 2-4 plot each column
# list of all column headers
columns= df.columns.to_list()

# creatining a for-loop to plot each column
for i in range(len(columns)):
    # print(columns[i])
    
    barplot(df, columns[i])
    
    # sns.countplot(x=df[columns[i]], palette='Set1', hue=df[columns[i]], legend=False, order=df[columns[i]].value_counts().index) #8 add ordering
    # # 6 # rotates the value labels slightly so they don’t overlap, also slightly increases font size
    # plt.xticks(rotation=30, fontsize=10)
    # # increases the variable label font size slightly to increase readability
    # plt.xlabel(columns[i], fontsize=12)
    # # 7 add an informative title
    # plt.title(f"{columns[i]} Value Counts", fontsize=14)
    # plt.show()
    plt.clf()  # Clear the current figure to avoid overlap in plots

# %% [markdown]
# ## Cleaning the Bar Graphs
